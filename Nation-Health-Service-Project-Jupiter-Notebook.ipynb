# %% [markdown]
# Import the needed libraries.

# %%
import pandas as pd
import numpy as pn #we import the libraries needed for this session.

# %% [markdown]
# Load the files onto the notebook and sense check them.

# %%
nc = pd.read_excel('national_categories.xlsx')
ar = pd.read_csv('appointments_regional.csv')
ad = pd.read_csv('actual_duration.csv')
print(nc.shape) #check the number of rows and columns
print(nc.columns) #to give a list of the columns in the dataframe
print(nc.dtypes) #gives the data types of the values in the rows and the columns
nc #will give a snapshot of the firts 5 and last 5 rows of the dataframe.
# Out:
# (817394, 8)
# Index(['appointment_date', 'icb_ons_code', 'sub_icb_location_name',
#        'service_setting', 'context_type', 'national_category',
#        'count_of_appointments', 'appointment_month'],
#       dtype='object')
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# ...

# %%
#sense check the 'ar' dataframe, it's columns and datatype.
print(ar.shape)
print(ar.columns)
print(ar.dtypes)
ar.head()
# Out:
# (596821, 7)
# Index(['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type',
#        'appointment_mode', 'time_between_book_and_appointment',
#        'count_of_appointments'],
#       dtype='object')
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# ...

# %%
#Sense check the 'ad' dataframe, show its columns, datatype and the first and last 5 rows.
print(ad.shape)
print(ad.columns)
print(ad.dtypes)
ad.head()
# Out:
# (137793, 8)
# Index(['sub_icb_location_code', 'sub_icb_location_ons_code',
#        'sub_icb_location_name', 'icb_ons_code', 'region_ons_code',
#        'appointment_date', 'actual_duration', 'count_of_appointments'],
#       dtype='object')
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# ...

# %%
nc.isnull().any() #this code i to find out whether there are any missing values in any of the columns in the dataframe.
# Out:
# appointment_date         False
# icb_ons_code             False
# sub_icb_location_name    False
# service_setting          False
# context_type             False
# national_category        False
# count_of_appointments    False
# appointment_month        False
# dtype: bool

# %% [markdown]
# The above output shows that there are no missing values inany of the columns of the 'nc' dataframe.

# %%
ar.isnull().any() #check for missing values in any of the columns.
# Out:
# icb_ons_code                         False
# appointment_month                    False
# appointment_status                   False
# hcp_type                             False
# appointment_mode                     False
# time_between_book_and_appointment    False
# count_of_appointments                False
# dtype: bool

# %% [markdown]
# No missing values in the dataset

# %%
ad.isnull().any() #check for missing values in any of the rows or columns.
# Out:
# sub_icb_location_code        False
# sub_icb_location_ons_code    False
# sub_icb_location_name        False
# icb_ons_code                 False
# region_ons_code              False
# appointment_date             False
# actual_duration              False
# count_of_appointments        False
# dtype: bool

# %% [markdown]
# No missing values in this dataset.

# %% [markdown]
# Determine the descriptive statistics and metadata.

# %%
nc.info #this gives metadata about the dataset.
# Out:
# <bound method DataFrame.info of        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...

# %%
nc.describe() #descriptive stistics for the appointmrnts column of this dataset
# Out:
#                     appointment_date  count_of_appointments
# count                         817394          817394.000000
# mean   2022-01-16 00:50:35.860796160             362.183684
# min              2021-08-01 00:00:00               1.000000
# 25%              2021-10-25 00:00:00               7.000000
# 50%              2022-01-18 00:00:00              25.000000
# 75%              2022-04-07 00:00:00             128.000000
# max              2022-06-30 00:00:00           16590.000000
# std                              NaN            1084.576600

# %% [markdown]
# The ouput shows that there were an daily average of 362 appointments with the lowest number being 1 appointment and the highest being 16,590 appointments.

# %%
ar.info() #metadata for `the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB

# %%
ar.describe() #code to bring back the descriptive statistics.
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %% [markdown]
# Above shows that there was a daily average of 1244 appointments, lowest is 1 appointment and highest 211,265 appointments.

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB

# %%
ad.describe()
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %% [markdown]
# Above shows a daily average of 1219 appointments, , low of 1 appointment and high of 15,400 appointments.

# %% [markdown]
# PART 1:
# QUESTION 1. How many locations are there in the data set?

# %%
loct_name = nc['sub_icb_location_name'].nunique() #this code returns the number of unique Nhs Trust location entries in the column.
print("Number of different locations:", loct_name)
# Out:
# Number of different locations: 106

# %% [markdown]
# There are 106 locations in this dataset.

# %%
loc_name = nc['sub_icb_location_name'].value_counts() #this is an alternative code to return the different NHS locations in the data set.
print("Number of locations:", loc_name)
# Out:
# Number of locations: sub_icb_location_name
# NHS North West London ICB - W2U3Z              13007
# NHS Kent and Medway ICB - 91Q                  12637
# NHS Devon ICB - 15N                            12526
# NHS Hampshire and Isle Of Wight ICB - D9Y0V    12171
# NHS North East London ICB - A3A8R              11837
#                                                ...
# NHS North East and North Cumbria ICB - 00N      4210
# NHS Lancashire and South Cumbria ICB - 02G      4169
# NHS Cheshire and Merseyside ICB - 01V           3496
# NHS Cheshire and Merseyside ICB - 01T           3242
# NHS Greater Manchester ICB - 00V                2170
# Name: count, Length: 106, dtype: int64

# %% [markdown]
# At the bottom of the output, it shows that the count of the loactions is 106.

# %% [markdown]
# QUESTION 2: What are the five locations with the highest number of appointments?

# %%
nc_grouped = nc.groupby('sub_icb_location_name').count_of_appointments.sum() #get sum of appointment per location
sorted_nc_grouped = nc_grouped.sort_values(ascending = False) # sort the appointments per per loaction in descending order.
print("Top 5 locations with the highest appointments:", sorted_nc_grouped.head()) #get the top 5 locations with the highest appointments.
# Out:
# Top 5 locations with the highest appointments: sub_icb_location_name
# NHS North West London ICB - W2U3Z              12142390
# NHS North East London ICB - A3A8R               9588891
# NHS Kent and Medway ICB - 91Q                   9286167
# NHS Hampshire and Isle Of Wight ICB - D9Y0V     8288102
# NHS South East London ICB - 72Q                 7850170
# Name: count_of_appointments, dtype: int64

# %% [markdown]
# Output shows that NHS North West London, NHS North East London, NHS Kent and Medway, NHS Hampshire and Isle Of Wight and NHS South East London are the top 5 hospitals with the highest number of appointments. 72Q

# %% [markdown]
# QUESTION 3. How many service settings, context types, national categories, and appointment statuses are there?

# %%
serv_sett = nc['service_setting'].nunique() #to find out how many service settings are in the dataset
print("Number of service settings:", serv_sett)
# Out:
# Number of service settings: 5

# %% [markdown]
# There are 5 different sevice settings in the dataset.

# %%
cont_type = nc['context_type'].nunique() #to find out how many context types there are in the dataset
print("Number of context types:", cont_type)
# Out:
# Number of context types: 3

# %% [markdown]
# There are 3 different context types in the dataset.

# %%
nat_cat = nc['national_category'].nunique() #to find out how many categories there are in the natioanl category column
print("Number of national categories:", nat_cat)
# Out:
# Number of national categories: 18

# %% [markdown]
# There are 18 different categories in the national category column.

# %%
app_stat = ar['appointment_status'].nunique() #to find out the different types of appointment statuses
print("Number of appointment statuses:", app_stat)
# Out:
# Number of appointment statuses: 3

# %% [markdown]
# There are three different statuses as shown above.

# %% [markdown]
# QUESTION 4. Are there any comments regarding data quality or descriptive statistics worth noting for each of the data sets?

# %% [markdown]
# Answer: None at the moment.

# %% [markdown]
# QUESTION 5: Can you comment on other features (columns) that could potentially be useful in your analysis?

# %% [markdown]
# It will be useful to analyse the appaointments that were attended vs those that were not in the 'appointment_ststus column' in the 'ar' dataset, the durations in the 'actual_duration' in the 'ad' datasset, the time scales in all the datasets and how many appointments there were weekly, monthly, etc.

# %% [markdown]
# PART 2:
# QUESTION 1.Between what dates were appointments scheduled?

# %%
nc.dtypes #checking the date format
# Out:
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object

# %% [markdown]
# The 'appointment_date' column is the correct datetime format.

# %%
ad.dtypes #check for date format
# Out:
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object

# %% [markdown]
# The 'appointment date column is in string format and we need to convert it to datetime format.

# %%
from datetime import datetime #import the datetime module

# %%
ad['appointment_date'] = pd.to_datetime(ad['appointment_date'], format="%d-%b-%y") 
#syntax to change the date format in 'appointment_date' column from string to datetime format.
ad.dtypes #check if the data type of the column has changed
# Out:
# sub_icb_location_code                object
# sub_icb_location_ons_code            object
# sub_icb_location_name                object
# icb_ons_code                         object
# region_ons_code                      object
# appointment_date             datetime64[ns]
# actual_duration                      object
# count_of_appointments                 int64
# dtype: object

# %% [markdown]
# The data type in the column has now been changed from string format to datetime format.

# %%
ad.head() #sense check the dataframe to confirm changes.
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0       2021-12-01           31-60 Minutes                    364
# 1       2021-12-01           21-30 Minutes                    619
# ...

# %%
min(ad['appointment_date'])
# Out:
# Timestamp('2021-12-01 00:00:00')

# %%
max(ad['appointment_date'])
# Out:
# Timestamp('2022-06-30 00:00:00')

# %% [markdown]
# The appointments in the 'actual duration' dataset were scheduled between 1st December 2021 and 30th June 2022.

# %%
min(nc['appointment_date'])
# Out:
# Timestamp('2021-08-01 00:00:00')

# %%
max(nc['appointment_date'])
# Out:
# Timestamp('2022-06-30 00:00:00')

# %% [markdown]
# The appointments in the 'national categories' dataset were scheduled between 1st August 2021 and 30th June 2022.

# %% [markdown]
# QUESTION 2. Which service setting reported the most appointments in North West London from 1 January to 1 June 2022?

# %%
#subset the dataset to get only the needed columns.
nc_subset = pd.read_excel('national_categories.xlsx',
                          usecols= ['appointment_date',
                                   'sub_icb_location_name',
                                   'service_setting',
                                   'count_of_appointments'])
nc_subset.head()
# Out:
#   appointment_date                       sub_icb_location_name  \
# 0       2021-08-02  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02  NHS North East and North Cumbria ICB - 00L
#
#         service_setting  count_of_appointments
# 0  Primary Care Network                      3
# 1                 Other                      7
# 2      General Practice                     79
# 3      General Practice                    725
# 4      General Practice                      2

# %%
nt_wst_ldn = nc_subset[nc_subset['sub_icb_location_name']== 'NHS North West London ICB - W2U3Z'] #filter for specified location
print(nt_wst_ldn.shape)
nt_wst_ldn.head()
# Out:
# (13007, 4)
#        appointment_date              sub_icb_location_name   service_setting  \
# 794321       2021-08-01  NHS North West London ICB - W2U3Z          Unmapped
# 794322       2021-08-01  NHS North West London ICB - W2U3Z             Other
# 794323       2021-08-01  NHS North West London ICB - W2U3Z  General Practice
# 794324       2021-08-01  NHS North West London ICB - W2U3Z  General Practice
# 794325       2021-08-01  NHS North West London ICB - W2U3Z  General Practice
#
#         count_of_appointments
# 794321                    607
# 794322                      6
# 794323                     47
# 794324                     74
# 794325                     98

# %%
#set the date range
start_date = '2022-01-01'
end_date = '2022-06-01'
nw_london_filtered = nt_wst_ldn[(nt_wst_ldn['appointment_date'] >= start_date) & 
                                (nt_wst_ldn['appointment_date'] < end_date)]

# %%
appointments_by_service = nw_london_filtered.groupby('service_setting')['count_of_appointments'].sum() #get the sum of the appointments

# %%
max_service_setting = appointments_by_service.idxmax() #return the rows with the highest value.
print(max_service_setting)
# Out:
# General Practice

# %%
max_appointments = appointments_by_service.max()
print("General Practice:", max_appointments)
# Out:
# General Practice: 4760966

# %% [markdown]
# General Practice is the service setting in NHS North West London with the most appointments between January and June 2022.

# %% [markdown]
# QUESTION 3. Which month had the highest number of appointments?

# %%
nc['appointment_date'].groupby([nc['appointment_date'].dt.year, nc['appointment_date'].dt.month])
#extract the months from the appointments dates

# %%
monthly_appointments_sum = nc.groupby('month')['count_of_appointments'].sum().sort_values() #calculate the sum of appointments per month

# %%
print("Appointments by month:", monthly_appointments_sum)

# %% [markdown]
# November had 30,405,070 appointments making it the month with the hoghest number of appointments.

# %% [markdown]
# QUESTION 4. What was the total number of records per month?

# %%
#Records for 'national categories' data source
nc_mnthly_appts_sum = nc.groupby('month')['count_of_appointments'].sum().sort_values()
print("'National Categories Records'", nc_mnthly_appts_sum)
# Out:
# 'National Categories Records' month
# 8     23852171
# 4     23913060
# 12    25140776
# 2     25355260
# 1     25635474
# 6     25828078
# 5     27495508
# 9     28522501
# 3     29595038
# 10    30303834
# 11    30405070
# Name: count_of_appointments, dtype: int64

# %% [markdown]
# The appointment records for each month of the National categories dataset is as shown above.

# %%
ad['month'] = ad['appointment_date'].dt.month #extract 'month' from appointment date

# %%
ad_mnthly_appts_sum = ad.groupby('month')['count_of_appointments'].sum().sort_values()
print("'Actual Duration Records'", ad_mnthly_appts_sum) #get the sum records for each month in ascending order.
# Out:
# 'Actual Duration Records' month
# 4     21948814
# 12    22853483
# 2     23351939
# 1     23597196
# 6     23715317
# 5     25343941
# 3     27170002
# Name: count_of_appointments, dtype: int64

# %% [markdown]
# The appointment records for each month of the Actual Duration dataset is as shown above.

# %% [markdown]
# TRENDS OBSERVED:
# The general Practice sector had the highest number of appointments.
# November was the busiest month the highest nunmer of appointments.

# %% [markdown]
# PART 3: VISUALIZATION.
# Objective 1: Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %%
#a. Import visualizatin libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Change the data type of appointment_month to string for ease of visualisation.

# %%
nc.dtypes
# Out:
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object

# %%
nc['appointment_month'] = nc['appointment_month'].astype(str)
print(nc.dtypes)
nc
# Out:
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# ...

# %%
#b. Aggregate the appointments per month, and determine the sum of the appointments per month
nc['month'] = nc['appointment_date'].dt.month

# %%
nc_ss = nc.groupby(['month', 'service_setting'])['count_of_appointments'].sum().reset_index()
print(nc_ss)
# Out:
#     month            service_setting  count_of_appointments
# 0       1  Extended Access Provision                 186375
# 1       1           General Practice               23583053
# 2       1                      Other                 457440
# 3       1       Primary Care Network                 569044
# 4       1                   Unmapped                 839562
# 5       2  Extended Access Provision                 196627
# 6       2           General Practice               23305934
# 7       2                      Other                 456153
# 8       2       Primary Care Network                 585300
# 9       2                   Unmapped                 811246
# 10      3  Extended Access Provision                 231905
# 11      3           General Practice               27187368
# 12      3                      Other                 530677
# 13      3       Primary Care Network                 702176
# 14      3                   Unmapped                 942912
# ...

# %% [markdown]
# The ouput shows the total number of appointments per service setting per month.

# %%
#c. Create a lineplot with Seaborn.
plt.figure(figsize=(15, 12))
sns.lineplot(data=nc_ss, x='month', y='count_of_appointments', hue='service_setting', errorbar=None)
sns.set_style("white")
# Adding titles and labels
plt.title('Monthly Appointments by Service Setting', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of Appointments (Millions)', fontsize=14)
plt.savefig('monthly_appointments_by_service_setting.png', format='png', dpi=300)

# Show the plot
plt.show()
# Out:
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Above plot shows monthly appointments by service setting. Genaral practice has the most appointments per month across all months while Extended Service Provision has the lowest number of appointments per month.

# %% [markdown]
# Repeat steps b and c for the context types and national categories.

# %%
#Get sum of appointments per month per context type.
nc_ct = nc.groupby(['month', 'context_type'])['count_of_appointments'].sum().reset_index()
nc_ct
# Out:
#     month            context_type  count_of_appointments
# 0       1  Care Related Encounter               22441947
# 1       1    Inconsistent Mapping                2353965
# 2       1                Unmapped                 839562
# 3       2  Care Related Encounter               22211021
# 4       2    Inconsistent Mapping                2332993
# 5       2                Unmapped                 811246
# 6       3  Care Related Encounter               25928850
# 7       3    Inconsistent Mapping                2723276
# 8       3                Unmapped                 942912
# 9       4  Care Related Encounter               20904193
# 10      4    Inconsistent Mapping                2248554
# 11      4                Unmapped                 760313
# 12      5  Care Related Encounter               24101243
# 13      5    Inconsistent Mapping                2573495
# 14      5                Unmapped                 820770
# ...

# %%
# Pivot the DataFrame to get context_type as columns
nc_ct_pivot = nc_ct.pivot(index='month', columns='context_type', values='count_of_appointments')

# %%
#plot a stcked bar caht to visualize the data
nc_ct_pivot.plot(kind='bar', stacked=True, figsize=(15, 12))

# Add labels and title
plt.xlabel('Month')
plt.ylabel('Count of Appointments (Millions)')
plt.title('Appointments per Month by Context Type')
plt.legend(title='Context Type')
plt.savefig('appointments_per_month_by_context_type.png', format='png', dpi=300)

# Display the plot
plt.show()

# %% [markdown]
# The above ouput shows that Care Related Encounter context had the highset number of appointments per month across all months while unmapped context and the lowest.

# %%
#Get sum of appointments per month for national categories.
nc_nc = nc.groupby(['month', 'national_category'])['count_of_appointments'].sum().reset_index()
print(nc_nc)
# Out:
#      month                                  national_category  \
# 0        1  Care Home Needs Assessment & Personalised Care...
# 1        1                                    Care Home Visit
# 2        1                                    Clinical Triage
# 3        1                         General Consultation Acute
# 4        1                       General Consultation Routine
# ..     ...                                                ...
# 193     12                         Social Prescribing Service
# 194     12                       Structured Medication Review
# 195     12                                           Unmapped
# 196     12                        Unplanned Clinical Activity
# 197     12                                            Walk-in
#
#      count_of_appointments
# 0                    37988
# 1                    55860
# 2                  3777487
# 3                  4787643
# 4                  8645563
# ..                     ...
# ...

# %%
#create pivot table
pivot_table = nc_nc.pivot(index='national_category', columns='month', values='count_of_appointments')

# Print the pivot table to check the structure
pivot_table
# Out:
# month                                                    1        2   \
# national_category
# Care Home Needs Assessment & Personalised Care ...    37988    37219
# Care Home Visit                                       55860    55078
# Clinical Triage                                     3777487  3646672
# General Consultation Acute                          4787643  4767965
# General Consultation Routine                        8645563  8565715
# Group Consultation and Group Education                 5108     5397
# Home Visit                                           184279   183418
# Inconsistent Mapping                                2353965  2332993
# Non-contractual chargeable work                       12121    12650
# Patient contact during Care Home Round                74860    77638
# Planned Clinical Procedure                          1957081  1956726
# Planned Clinics                                     2329241  2321981
# ...

# %%
plt.figure(figsize=(15, 12))  # Adjust the figure size to accommodate the number of categories
sns.heatmap(pivot_table, cmap="YlGnBu", linewidths=.5)

# Add titles and labels
plt.title('Monthly Sum of Appointments per National Category', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('National Category', fontsize=14)
plt.savefig('monthly_sum_of_appointments_per_national_category.png', format='png', dpi=300)

# Show the plot
plt.show()

# %% [markdown]
# The heatmap above shows number of appointments per category per month using colour. The more intense the colour, thr higher the appointments. General Consultation Routine has the highest number of appointments across all months while Walk in, Home visit categories among others have the lowest count per month.

# %% [markdown]
# Objective 2;
# Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (June to August 2021), autumn (September to November 2021), winter (December to February 2022), and spring (March to May 2022).

# %%
# Define a function to categorize months into seasons
def get_season(month):
    if month in [6, 7, 8]:
        return 'Summer 2021'
    elif month in [9, 10, 11]:
        return 'Autumn 2021'
    elif month in [12, 1, 2]:
        return 'Winter 2021-2022'
    elif month in [3, 4, 5]:
        return 'Spring 2022'

# Apply the function to create a new 'season' column
nc_ss['season'] = nc_ss['month'].apply(get_season)

# %%
#create new dataframe that has the added 'seasons' column
nc_ss_day = nc_ss.groupby(['season', 'service_setting'])['count_of_appointments'].sum().reset_index()
nc_ss_day
# Out:
#               season            service_setting  count_of_appointments
# 0        Autumn 2021  Extended Access Provision                 605022
# 1        Autumn 2021           General Practice               81314881
# 2        Autumn 2021                      Other                1642445
# 3        Autumn 2021       Primary Care Network                1709790
# 4        Autumn 2021                   Unmapped                3959267
# 5        Spring 2022  Extended Access Provision                 644700
# 6        Spring 2022           General Practice               74342779
# 7        Spring 2022                      Other                1471406
# 8        Spring 2022       Primary Care Network                2020726
# 9        Spring 2022                   Unmapped                2523995
# 10       Summer 2021  Extended Access Provision                 370579
# 11       Summer 2021           General Practice               45256226
# ...

# %%
#1. We can use a grouped barcahrt to visualize the above information
plt.figure(figsize=(12, 8))
sns.barplot(x='season', y='count_of_appointments', hue='service_setting', data=nc_ss_day)
plt.title('Number of Appointments per Service Setting by Season')
plt.ylabel('Count of Appointments (Millions)')
plt.xlabel('Season')
plt.xticks(rotation=45)
plt.legend(title='Service Setting', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.savefig('number_of_appointments_per_service_setting_by_season_bar_plot.png', format='png', dpi=300)

plt.show()

# %% [markdown]
# The grouped boxplot above shows the General practice setting as having the highest number of appointments across alll seasons and the Extended Aceess Provision service setting having the lowest.

# %%
#We can also plot a stacked barchart to visualise the data.
# First, we create a pivot table for stacked bar chart
pivot_nc_ss_day = nc_ss_day.pivot_table(index='season', columns='service_setting', values='count_of_appointments')

# Plotting the stacked bar chart
pivot_nc_ss_day.plot(kind='bar', stacked=True, figsize=(15, 12))
plt.title('Number of Appointments per Service Setting by Season')
plt.ylabel('Count of Appointments(Millions')
plt.xlabel('Season')
plt.xticks(rotation=45)
plt.legend(title='Service Setting', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.savefig('number_of_appointments_per_service_setting_by_season_stacked_bar.png', format='png', dpi=300)

plt.show()

# %% [markdown]
# Just like the grouped bar chart, the general practice is leading in the highest number of appointments per season while Extended Access Provision has the least.

# %%
#3. We can also use line plot to show the trend in appointment numbers across the seasons
plt.figure(figsize=(15, 12))
sns.lineplot(x='season', y='count_of_appointments', hue='service_setting', data=nc_ss_day, marker='o')
plt.title('Trend of Appointments per Service Setting by Season')
plt.ylabel('Count of Appointments (Millions)')
plt.xlabel('Season')
plt.xticks(rotation=45)
plt.legend(title='Service Setting', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.savefig('trend_of_appointments_per_service_setting_by_season_line_plot.png', format='png', dpi=300)

plt.show()
# Out:
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Across all service settings, there was a dip in appointment numbers in summer 2021. Autumn saw the highest number of appointments across all service sectors.

# %%
#4. Finally, a clusterd heatmap to visualize the data
sns.clustermap(nc_ss_day.pivot_table(index='season', columns='service_setting', values='count_of_appointments'), cmap='coolwarm')
plt.title('Appointments by Service Setting Across Seasons')
plt.savefig('appointments_by_service_setting_across_seasons.png', format='png', dpi=300)

plt.show()

# %% [markdown]
# The heatmap above shows the secotors and seasons with high number of appointements in red and low ones in blue.

# %% [markdown]
# PART 4
# OBJECTIVE: Identify and review the top trending hashtags (#) related to healthcare in the UK based on the data set received from the NHS.

# %%
#set figure size and plot style.
plt.figure(figsize=(15,12))
sns.set_style('white')
#set maximum column width of the dataframe to 200
pd.options.display.max_colwidth = 200

# %%
#load file and explore the data
nhs_tweets = pd.read_csv('tweets.csv')
print(nhs_tweets.shape)
print(nhs_tweets.columns)
nhs_tweets.head()
# Out:
# (1174, 10)
# Index(['tweet_id', 'tweet_full_text', 'tweet_entities',
#        'tweet_entities_hashtags', 'tweet_metadata', 'tweet_retweet_count',
#        'tweet_favorite_count', 'tweet_favorited', 'tweet_retweeted',
#        'tweet_lang'],
#       dtype='object')
#               tweet_id  \
# 0  1567629223795527681
# 1  1567582846612553728
# 2  1567582787070304256
# 3  1567582767625428992
# 4  1567582720460570625
#
#                                                                                                                                                                                            tweet_full_text  \
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# ...

# %%
nhs_tweets.info
nhs_tweets.describe
# Out:
# <bound method NDFrame.describe of                  tweet_id  \
# 0     1567629223795527681
# 1     1567582846612553728
# 2     1567582787070304256
# 3     1567582767625428992
# 4     1567582720460570625
# ...                   ...
# 1169  1567583004209332227
# 1170  1567582945342267393
# 1171  1567582936014241792
# 1172  1567582892892782592
# 1173  1567582846847533058
#
#                                                                                                                                                                                               tweet_full_text  \
# 0     As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# ...

# %%
#Explore the tweet_retweet_count and tweet_favorite_count columns with the value_counts()
count_retweet = nhs_tweets['tweet_retweet_count'].value_counts()
print("Count of the no. of times a tweet was retweeted:", count_retweet)
# Out:
# Count of the no. of times a tweet was retweeted: tweet_retweet_count
# 0      526
# 1      215
# 2      114
# 3       70
# 5       35
# 4       27
# 7       18
# 12      16
# 8       15
# 73      14
# 9       13
# 6       12
# 208     12
# 35      10
# 37       6
# 11       6
# 10       5
# 53       5
# 44       4
# 150      4
# 63       4
# 76       3
# 85       3
# 41       3
# 62       3
# 207      3
# 68       3
# 78       2
# 23       2
# 24       2
# 72       2
# 16       2
# 13       1
# 49       1
# 48       1
# 15       1
# 107      1
# 14       1
# 79       1
# 20       1
# 39       1
# 19       1
# 303      1
# 57       1
# 40       1
# 54       1
# 169      1
# Name: count, dtype: int64

# %%
tweet_favourited = nhs_tweets['tweet_favorite_count'].value_counts()
print("Count of no. of times a tweet was favourited:", tweet_favourited)
# Out:
# Count of no. of times a tweet was favourited: tweet_favorite_count
# 0     1027
# 1       91
# 2       16
# 3       13
# 4        7
# 5        5
# 6        2
# 17       1
# 12       1
# 10       1
# 8        1
# 13       1
# 11       1
# 7        1
# 20       1
# 28       1
# 14       1
# 18       1
# 9        1
# 42       1
# Name: count, dtype: int64

# %% [markdown]
# It would be important to look at the above two columns in more detail, look at the tweets that were retweeted and favourited many times, look at the content of these tweets and find out any common themes among them.

# %%
#Review the hashtags

# %%
#Create new data farame with only text values
tweets_text = nhs_tweets[['tweet_id', 'tweet_full_text', 'tweet_entities',
       'tweet_entities_hashtags', 'tweet_metadata', 'tweet_favorited', 'tweet_retweeted',
       'tweet_lang']]
tweets_text
# Out:
#                  tweet_id  \
# 0     1567629223795527681
# 1     1567582846612553728
# 2     1567582787070304256
# 3     1567582767625428992
# 4     1567582720460570625
# ...                   ...
# 1169  1567583004209332227
# 1170  1567582945342267393
# 1171  1567582936014241792
# 1172  1567582892892782592
# 1173  1567582846847533058
#
#                                                                                                                                                                                               tweet_full_text  \
# 0     As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                 RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# ...

# %%
#Create a variable (tags), and assign an empty list to it.
#Use a for loop, and specify the iterator_variable and the sequence.
tags = []
for y in [x.split(' ') for x in tweets_text['tweet_full_text'].values]:
        for z in y:
            if '#' in z:
                tags.append(z.lower()) #change to lowercase

# %%
#Create a Pandas Series to count the values in the list. Set the Series equal to tags.
#Display the first 30 records.
tags[:30]
# Out:
# ['#healthcare',
#  '#premisehealth',
#  '#hiring',
#  '#healthcare',
#  '🚨#new:🚨',
#  'look!\n\n#blogs',
#  '#digitaltransformation',
#  '#cybersecurity',
#  '#accounting',
#  '#finance',
#  '#healthcare',
#  'https://t.co/jrgqeqdme4\n.\n#firstcoastcna',
#  '#cnaexam',
#  '#cnaexampreparation',
#  '#jacksonville',
#  '#cnatraining',
#  '#nurse',
#  '#nursing',
#  '#nurselife',
#  '#nursepractitioner',
#  '#nurseproblems',
#  '#nursingschool',
#  '#healthcare',
#  '🚨#new:🚨',
#  '#disparities.',
#  '@karahartnett\n#healthcare',
#  '#alert',
#  '#insurance',
#  '#data\nhttps://t.co/h9hlamr7p9',
#  '#healthcare']

# %%
tags_series=pd.Series(tags) #create a pandas series to contain the list

# %%
#Identify the top trending hashtags with a visualisation

# %%
#convert the tags_series into a data frame
data = tags_series.value_counts().reset_index()
data.columns = ['word', 'count']
print(data)
# Out:
#                word  count
# 0       #healthcare    716
# 1           #health     80
# 2         #medicine     41
# 3               #ai     40
# 4              #job     38
# ...             ...    ...
# 1749      #evestudy      1
# 1750  #patientdata…      1
# 1751        #secure      1
# 1752           #sms      1
# 1753       \n#csjmu      1
#
# [1754 rows x 2 columns]

# %%
data.dtypes #sense check the data type of each column
# Out:
# word     object
# count     int64
# dtype: object

# %% [markdown]
# Create a Seaborn barplot of all records with a count>10.
# Remove any overrepresented hashtags and create a seaborn barplot displaying the remaining most frequently used hashtags (#).

# %%
# Step 1: Filter out hashtags with count > 10
filtered_data = data[data['count'] > 10]

# %%
# Step 2: Remove overrepresented hashtags (e.g., the top one or two)
# Let's assume '#healthcare' is overrepresented and needs to be removed
filtered_data = filtered_data[filtered_data['word'] != '#healthcare']

# %%
# Step 3: Create a Seaborn barplot
plt.figure(figsize=(15, 12))
sns.barplot(x='count', y='word', data=filtered_data, palette='viridis')
plt.title('Most Frequently Used Hashtags (Count > 10, Excluding Overrepresented)')
plt.xlabel('Count')
plt.ylabel('Hashtag')
plt.savefig('most_frequently_used_hashtags.png', format='png', dpi=300)

plt.show()

# %% [markdown]
# Explore how you can improve the above visualisation:
# Answer: there are too many rows of hashtags to be visualise. It would be better if only the most important hastags were chosen.

# %% [markdown]
# How can your team can utilise tweets to provide feedback to the stakeholders?
# Answer: If there are tweets that provide more information about the business problem or contain slues and solutions on what could be done better by the stakeholders, then the information from the tweets can be used to better services offerd to their clients.

# %% [markdown]
# Do the tweets add value to the overall project?
# Answer: The tweets in the dataset do not seem to provide any feedback directly related to the project at hand.

# %% [markdown]
# How the NHS can utilise tweets.
# Answer: The NHS can analyse tweets to find information that would be useful to them and their customers. The can put out information about themselves and the servises they offfer and any general medical education information they wish to pass across. They can also have people give feeedback about theur services.

# %% [markdown]
# Any suggestions regarding data collection or analysis to improve future efforts.
# Answer: collect only data that is relevant to their sector and do indepth analysis to it.

# %% [markdown]
# Summarise any insights you've discovered and anything you would like to explore further. For example, indicate the steps you followed to improve the visualisations to optimise feedback to your team and the NHS.
# Answer: There is not enough information gathered from the tweets that can helpe answer the questions at hand about the capacity of the NHS and the reasons for missed appointments. We recommend getting more tweets and explore them further.

# %% [markdown]
# PART 5: MAKING RECOMMENDATIONS
# Review the findings and trends you've identified during your data analysis. Based on your understanding of the data, formulate questions to make recommendations to the NHS.
# The questions to use to make recommendations are:
# 1. Should the NHS start looking at increasing staff levels?
# 2.
# How do the healthcare professional types differ over time?3.
# Are there significant changes in whether or not visits are attended4. ?
# Are there changes in terms of appointment type and the busiest month5. s?
# Are there any trends in time between booking and appointme5. nt?
# How do the various service settings compare?

# %%
#Load the appointments_regional.csv file and create a DataFrame (e.g. ar) to store the data set.
ar = pd.read_csv('appointments_regional.csv')
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
#Print the minimum and maximum dates pertaining to the ar data set.

# %%
ar['appointment_month'].min()
# Out:
# '2020-01'

# %%
ar['appointment_month'].max()
# Out:
# '2022-06'

# %%
#Filter the data set to only look at the data from 2021-08 onwards.
#View the DataFrame.

# %%
# Convert 'appointment_month' to datetime
ar['appointment_month'] = pd.to_datetime(ar['appointment_month'], format='%Y-%m')

# %%
# Filter the data from August 2021 onwards
filtered_ar = ar[ar['appointment_month'] >= '2021-08']
# View the filtered DataFrame
filtered_ar
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 3652      E54000034        2021-08-01           Attended       GP
# 3653      E54000034        2021-08-01           Attended       GP
# 3654      E54000034        2021-08-01           Attended       GP
# 3655      E54000034        2021-08-01           Attended       GP
# 3656      E54000034        2021-08-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050        2022-06-01            Unknown  Unknown
# 596817    E54000050        2022-06-01            Unknown  Unknown
# 596818    E54000050        2022-06-01            Unknown  Unknown
# 596819    E54000050        2022-06-01            Unknown  Unknown
# 596820    E54000050        2022-06-01            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 3652       Face-to-Face                             1 Day
# ...

# %% [markdown]
# Answer the questions from the objective.
# Q1. Should the NHS start looking at increasing staff levels?

# %%
#Create a new DataFrame (e.g. ar_agg) to review the different features.

# %%
# Group by the selected columns and calculate the sum of 'count_of_appointments'
ar_agg = ar.groupby(['appointment_month', 'hcp_type', 'appointment_status', 'appointment_mode', 'time_between_book_and_appointment'])['count_of_appointments'].sum().reset_index()

# View the new DataFrame
ar_agg.head()
# Out:
#   appointment_month hcp_type appointment_status appointment_mode  \
# 0        2020-01-01       GP           Attended     Face-to-Face
# 1        2020-01-01       GP           Attended     Face-to-Face
# 2        2020-01-01       GP           Attended     Face-to-Face
# 3        2020-01-01       GP           Attended     Face-to-Face
# 4        2020-01-01       GP           Attended     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                 653846
# 1                    15  to 21 Days                 620789
# 2                       2 to 7 Days                1723834
# 3                    22  to 28 Days                 421189
# 4                     8  to 14 Days                1123186

# %%
#Determine average utilisation of services:

# %%
# Group by 'appointment_month' and sum 'count_of_appointments'
ar_df = ar_agg.groupby('appointment_month')['count_of_appointments'].sum().reset_index()

# %%
# Calculate the utilisation as a percentage of the maximum capacity
ar_df['utilisation'] = (ar_df['count_of_appointments'] / 30) / 1200000 * 100

# %%
# Round the utilisation to one decimal place
ar_df['utilisation'] = ar_df['utilisation'].round(1)

# View the new DataFrame
ar_df
# Out:
#    appointment_month  count_of_appointments  utilisation
# 0         2020-01-01               27199296         75.6
# 1         2020-02-01               24104621         67.0
# 2         2020-03-01               24053468         66.8
# 3         2020-04-01               16007881         44.5
# 4         2020-05-01               16417212         45.6
# 5         2020-06-01               20690805         57.5
# 6         2020-07-01               22491437         62.5
# 7         2020-08-01               20150520         56.0
# 8         2020-09-01               26714255         74.2
# 9         2020-10-01               28301932         78.6
# 10        2020-11-01               25061602         69.6
# 11        2020-12-01               23535936         65.4
# 12        2021-01-01               22492069         62.5
# 13        2021-02-01               22399569         62.2
# 14        2021-03-01               27225424         75.6
# ...

# %%
#Create two lineplots with Seaborn:

# %%
# Convert 'appointment_month' to string
ar_df['appointment_month'] = ar_df['appointment_month'].astype(str)
# Set the style of seaborn plots
sns.set(style='whitegrid')

# %%
# Create the first lineplot for number of monthly visits
plt.figure(figsize=(15, 12))
sns.lineplot(x='appointment_month', y='count_of_appointments', data=ar_df, marker='o')
plt.title('Number of Monthly Visits')
plt.xlabel('Month')
plt.ylabel('Number of Appointments (Millions)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Create the second lineplot for monthly capacity utilisation
plt.figure(figsize=(15, 12))
sns.lineplot(x='appointment_month', y='utilisation', data=ar_df, marker='o', color='orange')
plt.title('Monthly Capacity Utilisation')
plt.xlabel('Month')
plt.ylabel('Utilisation (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('monthly_capacity_utilisation.png', format='png', dpi=300)

plt.show()
# Out:
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Answer:
# As the baove data and lineplots indicate, the capacity is not maximum yet. The highest utilisation percentage was 84.5% (30,405,070 appointments), which comes to just under the 1, 200, 000 appointments a day that had been set as the capcity. The Nhs does not need to increase staffing leveles but use the current staff numbers efficiently.

# %% [markdown]
# Q2: How do the healthcare professional types differ over time?

# %%
How do the healthcare professional types differ over time?

# %%
# Set the style of seaborn plots
sns.set(style='whitegrid')

# Create the lineplot
plt.figure(figsize=(15, 12))
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='hcp_type', data=ar_agg, marker='o')

# Customize the plot
plt.title('Number of Appointments per Month by Healthcare Professional Type')
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Healthcare Professional Type')
plt.tight_layout()  # Adjust layout to make room for the legend
plt.savefig('number_of_appointments_per_month_by_healthcare_professional_type.png', format='png', dpi=300)

plt.show()
# Out:
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Answer: Overtime, General practice Doctors have the most appointments closely followed by other practice staff. NHS should look into supporting the GPs to to the pressure of hight appointment numbers on them.

# %% [markdown]
# Q3. Are there significant changes in whether or not visits are attended?

# %%
# Set the style of seaborn plots
sns.set(style='whitegrid')

# Create the lineplot
plt.figure(figsize=(15, 12))
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='appointment_status', data=ar_agg, marker='o')

# Customize the plot
plt.title('Number of Appointments Over Time by Status')
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments (Millions)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Appointment Status')
plt.tight_layout()  # Adjust layout to make room for the legend
plt.savefig('number_of_appointments_over_time_by_status.png', format='png', dpi=300)

plt.show()
# Out:
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Answer: The attendance ststus did not signficantly affect appointment numbers.

# %% [markdown]
# Q4. Are there changes in terms of appointment type and the busiest months?

# %%
# Set the style of seaborn plots
sns.set(style='whitegrid')

# Create the lineplot
plt.figure(figsize=(14, 7))
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='appointment_mode', data=ar_agg, marker='o')

# Customize the plot
plt.title('Number of Appointments by Appointment Mode Over Time')
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments (Millions)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Appointment Mode')
plt.tight_layout()  # Adjust layout to make room for the legend
plt.savefig('number_of_appointments_by_appointment_mode_over_time.png', format='png', dpi=300)

plt.show()
# Out:
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Answer:
# The busiest months saw a rise in face to face appointments.
# This revelation can help the NHS to equip their facilities better  to help cope with the increase in numbers during the anticipated busy months.

# %%
# Define the function to convert time intervals to numeric days
def convert_to_days(time_str):
    try:
        if 'Day' in time_str:
            return int(time_str.split()[0])
        elif 'to' in time_str:
            parts = time_str.split('to')
            return (int(parts[0].strip().split()[0]) + int(parts[1].strip().split()[0])) / 2
        else:
            # Handle unexpected values
            return None
    except ValueError:
        return None

# %%
# Apply the conversion function and handle missing values
ar_agg['time_between_book_and_appointment_days'] = ar_agg['time_between_book_and_appointment'].apply(convert_to_days)

# %%
# Inspect the DataFrame
ar_agg.head()
# Out:
#   appointment_month hcp_type appointment_status appointment_mode  \
# 0        2020-01-01       GP           Attended     Face-to-Face
# 1        2020-01-01       GP           Attended     Face-to-Face
# 2        2020-01-01       GP           Attended     Face-to-Face
# 3        2020-01-01       GP           Attended     Face-to-Face
# 4        2020-01-01       GP           Attended     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments  \
# 0                             1 Day                 653846
# 1                    15  to 21 Days                 620789
# 2                       2 to 7 Days                1723834
# 3                    22  to 28 Days                 421189
# 4                     8  to 14 Days                1123186
#
#    time_between_book_and_appointment_days
# 0                                     1.0
# 1                                    15.0
# 2                                     2.0
# 3                                    22.0
# ...

# %%
# Aggregate the data
agg_df = ar_agg.groupby(['appointment_month', 'time_between_book_and_appointment_days'])['count_of_appointments'].sum().reset_index()
# Display the aggregated DataFrame
agg_df.head()
# Out:
#   appointment_month  time_between_book_and_appointment_days  \
# 0        2020-01-01                                     1.0
# 1        2020-01-01                                     2.0
# 2        2020-01-01                                     8.0
# 3        2020-01-01                                    15.0
# 4        2020-01-01                                    22.0
#
#    count_of_appointments
# 0                1945711
# 1                5604909
# 2                3444637
# 3                1881819
# 4                1313557

# %%
# Set the style of seaborn plots
sns.set(style='whitegrid')

# Create the lineplot
plt.figure(figsize=(15, 12))
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='time_between_book_and_appointment_days', data=agg_df, marker='o')

# Customize the plot
plt.title('Number of Appointments by Time Between Booking and Appointment')
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments (Millions)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Days Between Booking and Appointment')
plt.tight_layout()  # Adjust layout to make room for the legend
plt.savefig('number_of_appointments_by_time_between_booking_and_appointment.png', format='png', dpi=300)

plt.show()
# Out:
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\antho\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Answer: There is no significant relationship between booking appointment and appointment  numbers.

# %% [markdown]
# 6. How do the various service settings compare?

# %%
#View the national_category.csv DataFrame you created in an earlier activity.

# %%
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Aggregate the data to get the total number of appointments per service setting
agg_nc = nc.groupby('service_setting')['count_of_appointments'].sum().reset_index()
# Create the bar plot
plt.figure(figsize=(15, 12))
sns.barplot(x='service_setting', y='count_of_appointments', data=agg_nc, palette='viridis')

# Customize the plot
plt.title('Total Number of Appointments by Service Setting')
plt.xlabel('Service Setting')
plt.ylabel('Number of Appointments (Millions)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.savefig('total_appointments_by_service_setting.png', format='png', dpi=300)

plt.show()

# %% [markdown]
# Answer: General practice has by far the highest number of appointments compared to other service settings. Extended Access Provision has the lowest.
# Staff numbers could be leveraged to supply different service sectors staff numbers that correspond to the appointment numbers. In the above example, staff from the less busy settings could be reshufffled and reallocated to the busy ones on the busiest days or months.

# %%
# Filter out GP visits
filtered_nc = nc[nc['service_setting'] != 'General Practice']

# Aggregate the data by service setting
filtered_agg_nc = filtered_nc.groupby('service_setting')['count_of_appointments'].sum().reset_index()

# %%
# Create the bar plot
plt.figure(figsize=(15, 12))
sns.barplot(x='service_setting', y='count_of_appointments', data=filtered_agg_nc, palette='viridis')

# Customize the plot
plt.title('Total Number of Appointments by Service Setting (Excluding GP Visits)')
plt.xlabel('Service Setting')
plt.ylabel('Number of Appointments (Millions)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.savefig('appointments_by_service_setting(excluding_gp_visits.png', format='png', dpi=300)
plt.show()

# %% [markdown]
# Answer: This provides a better visualisation of the other service settings with General Practice. Unmapped setting has the highest  number of appointments while Extended Access Provision has the lowest. As previously suggested, staff could be reallocated from lesss busy settings to help their colleagues in the busier areas during busy periods.
